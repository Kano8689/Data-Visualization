# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# path = '/content/drive/MyDrive/Colab Notebooks/CSE5046/Datasets/car_dataset.csv'
# data = pd.read_csv(path, encoding='latin1')
# Out:
# Mounted at /content/drive

# %%
path = 'Dataset/car_dataset.csv'
data = pd.read_csv(path, encoding='latin1')

# %% [markdown]
# describe
# info
# shape
# head
# tail
# rename (if want)
# duplicate delete
# null

# %%
data.describe()
# Out:
#               Year   Engine HP  Engine Cylinders  Number of Doors  \
# count   191.000000  200.000000        175.000000       166.000000
# mean   2008.240838  231.240000          9.051429         4.626506
# std       8.204274   97.143071          5.721776         2.764322
# min    1995.000000   70.000000          3.000000         2.000000
# 25%    2001.000000  143.500000          4.000000         3.000000
# 50%    2009.000000  240.500000          8.000000         4.000000
# 75%    2016.000000  318.000000         12.000000         5.000000
# max    2021.000000  399.000000         20.000000        10.000000
#
#        highway MPG    city mpg  Popularity          MSRP
# count   195.000000  193.000000   200.00000    200.000000
# mean     30.779487   26.056995   491.43000  41570.800000
# std      23.953296   22.224280   276.21948  20392.372503
# min      10.000000    8.000000     8.00000   6651.000000
# 25%      19.000000   15.000000   242.00000  24544.500000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               158 non-null    object
#  1   Model              166 non-null    object
#  2   Year               191 non-null    float64
#  3   Engine Fuel Type   151 non-null    object
#  4   Engine HP          200 non-null    int64
#  5   Engine Cylinders   175 non-null    float64
#  6   Transmission Type  147 non-null    object
#  7   Driven_Wheels      156 non-null    object
#  8   Number of Doors    166 non-null    float64
#  9   Market Category    152 non-null    object
#  10  Vehicle Size       145 non-null    object
#  11  Vehicle Style      150 non-null    object
#  12  highway MPG        195 non-null    float64
#  13  city mpg           193 non-null    float64
#  14  Popularity         200 non-null    int64
#  15  MSRP               200 non-null    int64
# ...

# %%
data.shape
# Out:
# (200, 16)

# %%
data.head()
# Out:
#     Make Model    Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0    NaN     X     NaN              NaN         77              20.0
# 1  Honda   NaN  2020.0           Diesel        191              12.0
# 2    BMW     X  2001.0         Gasoline        233               4.0
# 3  Honda     B  2019.0         Electric        159              12.0
# 4  Honda     X  1998.0              NaN        205               8.0
#
#   Transmission Type Driven_Wheels  Number of Doors Market Category  \
# 0               NaN           FWD             10.0       Hatchback
# 1            Manual           FWD              3.0             NaN
# 2            Manual           FWD             10.0       Hatchback
# 3               CVT           RWD              3.0       Hatchback
# 4         Automatic           NaN              5.0          Luxury
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0          NaN         Sedan         32.0      20.0         930  44279
# ...

# %%
data.tail()
# Out:
#         Make Model    Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 195      BMW     Y  2018.0              NaN        188              20.0
# 196     Ford     Z  1997.0           Diesel         97               6.0
# 197      NaN     Y  2011.0              NaN        271               4.0
# 198      BMW     X  1997.0              NaN        108               8.0
# 199  Hyundai     A  2010.0              NaN        342              20.0
#
#     Transmission Type Driven_Wheels  Number of Doors Market Category  \
# 195               NaN           FWD             10.0       Hatchback
# 196         Automatic           FWD              NaN       Hatchback
# 197               CVT           RWD              3.0       Crossover
# 198         Automatic           FWD              2.0       Hatchback
# 199            Manual           NaN              5.0             NaN
#
#     Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %%
data.rename(columns={"Make":"Company","Engine Fuel Type":"Fuel Type", "highway MPG":"Highway MPG", "city mpg":"City MPG", "Engine HP":"HP", "Engine Cylinders":"Cylinders", "Driven_Wheels":"Driven Wheels"}, inplace=True)
data.head()
# Out:
#   Company Model    Year Fuel Type   HP  Cylinders Transmission Type  \
# 0     NaN     X     NaN       NaN   77       20.0               NaN
# 1   Honda   NaN  2020.0    Diesel  191       12.0            Manual
# 2     BMW     X  2001.0  Gasoline  233        4.0            Manual
# 3   Honda     B  2019.0  Electric  159       12.0               CVT
# 4   Honda     X  1998.0       NaN  205        8.0         Automatic
#
#   Driven Wheels  Number of Doors Market Category Vehicle Size Vehicle Style  \
# 0           FWD             10.0       Hatchback          NaN         Sedan
# 1           FWD              3.0             NaN      Compact         Truck
# 2           FWD             10.0       Hatchback          NaN           SUV
# 3           RWD              3.0       Hatchback      Midsize           SUV
# 4           NaN              5.0          Luxury      Compact           NaN
#
#    Highway MPG  City MPG  Popularity   MSRP
# 0         32.0      20.0         930  44279
# ...

# %%
duplicated_rows = data[data.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [Company, Model, Year, Fuel Type, HP, Cylinders, Transmission Type, Driven Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, Highway MPG, City MPG, Popularity, MSRP]
# Index: []

# %%
data.count()
# Out:
# Company              158
# Model                166
# Year                 191
# Fuel Type            151
# HP                   200
# Cylinders            175
# Transmission Type    147
# Driven Wheels        156
# Number of Doors      166
# Market Category      152
# Vehicle Size         145
# Vehicle Style        150
# Highway MPG          195
# City MPG             193
# Popularity           200
# MSRP                 200
# dtype: int64

# %%
data = data.drop_duplicates()
data.head(3)
# Out:
#   Company Model    Year Fuel Type   HP  Cylinders Transmission Type  \
# 0     NaN     X     NaN       NaN   77       20.0               NaN
# 1   Honda   NaN  2020.0    Diesel  191       12.0            Manual
# 2     BMW     X  2001.0  Gasoline  233        4.0            Manual
#
#   Driven Wheels  Number of Doors Market Category Vehicle Size Vehicle Style  \
# 0           FWD             10.0       Hatchback          NaN         Sedan
# 1           FWD              3.0             NaN      Compact         Truck
# 2           FWD             10.0       Hatchback          NaN           SUV
#
#    Highway MPG  City MPG  Popularity   MSRP
# 0         32.0      20.0         930  44279
# 1         40.0      38.0         778  28888
# 2         20.0      14.0         345  22630

# %%
data.count()
# Out:
# Company              158
# Model                166
# Year                 191
# Fuel Type            151
# HP                   200
# Cylinders            175
# Transmission Type    147
# Driven Wheels        156
# Number of Doors      166
# Market Category      152
# Vehicle Size         145
# Vehicle Style        150
# Highway MPG          195
# City MPG             193
# Popularity           200
# MSRP                 200
# dtype: int64

# %%
data1 = data.copy()

# %%
missing_data = data1.isnull().sum().reset_index()
missing_data.columns = ["Column","Missing Values"]
fig = px.bar(missing_data, x="Column", y="Missing Values", title="Missing Values in Each Column", color="Missing Values", color_continuous_scale="Blues", text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data["Highway MPG"].fillna(int(data["Highway MPG"].mean()), inplace=True)
data["City MPG"].fillna(int(data["City MPG"].mean()), inplace=True)
data["Cylinders"].fillna(int(data["Cylinders"].mode()), inplace=True)
data["Number of Doors"].fillna(int(data["Number of Doors"].mode()), inplace=True)
data["Year"].bfill(inplace=True)
data["Company"].fillna("Unknown", inplace=True)
data["Fuel Type"] = data["Fuel Type"].fillna(
    data.groupby("Company")["Fuel Type"].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else x)
)
data["Model"] = data["Model"].fillna(
    data.groupby("Company")["Model"].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else x)
)
data["Transmission Type"].bfill(inplace=True)
data["Driven Wheels"] = data['Driven Wheels'].fillna(
    data.groupby("Transmission Type")["Driven Wheels"].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else x)
)
data["Market Category"] = data["Market Category"].fillna(
    data.groupby(["Company","Number of Doors"])["Market Category"].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else x)
)
data["Vehicle Size"] = data["Vehicle Size"].fillna(
    data.groupby("Market Category")["Vehicle Size"].transform(
        lambda x: x.mode().iloc[0] if not x.mode().empty else "Unknown"
    )
)
data["Vehicle Style"] = data["Vehicle Size"].fillna(
    data.groupby(["Company","Market Category","Vehicle Size"])["Vehicle Style"].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else x)
)
# Out:
# /tmp/ipykernel_3159/1985368472.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# /tmp/ipykernel_3159/1985368472.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.head(20)
# Out:
#     Company Model    Year Fuel Type   HP  Cylinders Transmission Type  \
# 0   Unknown     X  2020.0  Gasoline   77       20.0            Manual
# 1     Honda     B  2020.0    Diesel  191       12.0            Manual
# 2       BMW     X  2001.0  Gasoline  233        4.0            Manual
# 3     Honda     B  2019.0  Electric  159       12.0               CVT
# 4     Honda     X  1998.0    Diesel  205        8.0         Automatic
# 5      Ford     Y  2007.0  Gasoline  255        3.0               CVT
# 6       BMW     B  2014.0  Electric  385        3.0               CVT
# 7       BMW     B  1995.0    Diesel  247       12.0               CVT
# 8       BMW     B  2002.0  Gasoline   97        8.0            Manual
# 9     Honda     Y  2008.0  Gasoline  289        3.0         Automatic
# 10  Unknown     Z  2010.0  Gasoline  110        8.0            Manual
# 11      BMW     X  2008.0  Gasoline  297        4.0            Manual
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            200 non-null    object
#  1   Model              200 non-null    object
#  2   Year               200 non-null    float64
#  3   Fuel Type          200 non-null    object
#  4   HP                 200 non-null    int64
#  5   Cylinders          200 non-null    float64
#  6   Transmission Type  200 non-null    object
#  7   Driven Wheels      200 non-null    object
#  8   Number of Doors    200 non-null    float64
#  9   Market Category    200 non-null    object
#  10  Vehicle Size       200 non-null    object
#  11  Vehicle Style      200 non-null    object
#  12  Highway MPG        200 non-null    float64
#  13  City MPG           200 non-null    float64
#  14  Popularity         200 non-null    int64
#  15  MSRP               200 non-null    int64
# ...

# %%
data.to_csv("/content/drive/MyDrive/Colab Notebooks/CSE5046/Datasets/car_dataset_cleaned.csv")

# %%
sns.countplot(x='Company', hue="Model", data=data)
plt.title('Car Company Names')
plt.show()

# %%
sns.countplot(x='Market Category', data=data)
plt.title('Market Category')
plt.show()

# %%
sns.countplot(x='Transmission Type', hue="Driven Wheels",data=data)
plt.title('Transmission Type')
plt.show()

# %%
sns.violinplot(x="Market Category", y="Popularity", hue="Transmission Type",data=data)
plt.show()

# %%
plt.figure(figsize=(10, 6))
company_counts = data['Company'].value_counts().nlargest(10).sort_values(ascending=False)
sns.barplot(x=company_counts.values, y=company_counts.index, palette='viridis')
plt.title('Top 10 Car Companies by Count', fontsize=14)
plt.xlabel('Number of Cars')
plt.ylabel('Company')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3159/160459350.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(10, 6))
fuel_msrp = data.groupby('Fuel Type')['MSRP'].mean().sort_values(ascending=False).reset_index()
sns.barplot(data=fuel_msrp, x='MSRP', y='Fuel Type', palette='magma')
plt.title('Average MSRP by Fuel Type', fontsize=14)
plt.xlabel('Average MSRP ($)')
plt.ylabel('Fuel Type')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3159/1491692918.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='HP', y='MSRP', hue='Fuel Type', alpha=0.7, s=100)
plt.title('Relationship: Horsepower (HP) vs. MSRP', fontsize=14)
plt.xlabel('Horsepower')
plt.ylabel('MSRP ($)')
plt.legend(title='Fuel Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
style_counts = data['Vehicle Style'].value_counts().sort_values(ascending=False)
sns.barplot(x=style_counts.values, y=style_counts.index, palette='coolwarm')
plt.title('Distribution of Vehicle Body Styles', fontsize=14)
plt.xlabel('Count')
plt.ylabel('Vehicle Style')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3159/2430206847.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(12, 6))
mpg_transmission = data.groupby('Transmission Type')[['Highway MPG', 'City MPG']].mean().reset_index()
mpg_melted = mpg_transmission.melt(id_vars='Transmission Type', var_name='MPG Type', value_name='Average MPG')

sns.barplot(data=mpg_melted, x='Transmission Type', y='Average MPG', hue='MPG Type', palette='Set2')
plt.title('Average MPG (Highway vs City) by Transmission Type', fontsize=14)
plt.xlabel('Transmission Type')
plt.ylabel('Average MPG')
plt.legend(title='MPG Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **16/04/2026 (T)**

# %%
sns.boxplot(x=data['MSRP'])
# Out:
# <Axes: xlabel='MSRP'>

# %%
sns.boxplot(x=data['HP'])
# Out:
# <Axes: xlabel='HP'>

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

print(IQR)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3159/908671303.py in <cell line: 0>()
# ----> 1 Q1 = data.quantile(0.25)
#       2 Q3 = data.quantile(0.75)
#       3 IQR = Q3 - Q1
#       4
#       5 print(IQR)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   12144             # error: List item 0 has incompatible type "float | ExtensionArray |
#   12145             # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12146             res_df = self.quantile(
#   12147                 [q],  # type: ignore[list-item]
#   12148                 axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   12189             )
#   12190         if method == "single":
# ...

# %% [markdown]
# **IQR = IQR focusses on middle portion ignoring extreme values. iqr is used to messure data spreads, detect outlier, understand valuation**
#
#
# [2, 5, 7, 10, 12, 15, 18, 20, 100]
#        |      |        |
#       Q1     IQR       Q3
#        7      11       18

# %%
data = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]
data.shape
perc25=data['price'].quantile(0.25)
perc75=data['price'].quantile(0.75)
IQR=perc75-perc25
upperlimit=perc75+1.5 *IQR
lowerlimit=perc25-1.5*IQR
newdata=data[~((data['price']<lowerlimit) |(data['price']>upperlimit)) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3159/1038464049.py in <cell line: 0>()
# ----> 1 data = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]
#       2 data.shape
#       3 perc25=data['price'].quantile(0.25)
#       4 perc75=data['price'].quantile(0.75)
#       5 IQR=perc75-perc25
#
# NameError: name 'Q1' is not defined

# %% [markdown]
# **Q1 should be numerical columan; checks all the column in the datasets is theere any value in a row as a outlier then it will delete entore row.**
#
# **25% lies below 25%**
#
# **75% lies above 75%**
